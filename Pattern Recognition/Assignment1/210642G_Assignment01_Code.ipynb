# %% [markdown]
# 1.

# %%
import numpy as np
import matplotlib . pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
import numpy as np
import matplotlib . pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# Generate 100 samples
n_samples = 100

# Generate X values ( uniformly distributed between 0 and 10)
X = 10*np.random.rand(n_samples , 1)

# Generate epsilon values ( normally distributed with mean 0 and standard deviation 15)
epsilon = np.random.normal(0 , 15 , n_samples )

# Generate Y values using the model Y = 3 + 3X + epsilon
Y = 3 + 2*X + epsilon[: , np.newaxis]

# %% [markdown]
# 2.

# %%
r = np.random.randint (104)

# Split the data into training and test sets (80% train ,20% test )
X_train , X_test , Y_train , Y_test = train_test_split (X , Y ,test_size =0.2 , random_state = r )

# Plot the data points 
plt.figure(figsize =(10 , 6))
plt.scatter(X_train , Y_train , alpha =1 , marker ='o', color ='red', label ='Training Data')
plt.scatter(X_test , Y_test , alpha =1 , marker ='s', color ='blue', label ='Testing Data')
plt.show()

# %% [markdown]
# 3.

# %%
for i in range (10) : # Plotting 10 different instances
    X_train , X_test , Y_train , Y_test = train_test_split (X ,Y , test_size =0.2 , random_state = np.random.randint(104))
    model = LinearRegression ()
    model.fit ( X_train , Y_train )
    Y_pred_train = model.predict( X_train )
    plt.plot( X_train , Y_pred_train , label = f'LR {i+1} ')

plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.show()

# %% [markdown]
# 4.

# %%
# Generate 100 samples
n_samples = 10000

# Generate X values ( uniformly distributed between 0 and 10)
X = 10*np.random.rand(n_samples , 1)

# Generate epsilon values ( normally distributed with mean 0 and standard deviation 15)
epsilon = np.random.normal(0 , 15 , n_samples )

# Generate Y values using the model Y = 3 + 3X + epsilon
Y = 3 + 2*X + epsilon[: , np.newaxis]

for i in range (10) : # Plotting 10 different instances
    X_train , X_test , Y_train , Y_test = train_test_split (X ,Y , test_size =0.2 , random_state = np.random.randint(104))
    model = LinearRegression ()
    model.fit ( X_train , Y_train )
    Y_pred_train = model.predict( X_train )
    plt.plot( X_train , Y_pred_train , label = f'LR {i+1} ')

plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.show()

# %% [markdown]
# 3.1.

# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
infrared_thermography_temperature = fetch_ucirepo(id=925) 
  
# data (as pandas dataframes) 
X = infrared_thermography_temperature.data.features 
y = infrared_thermography_temperature.data.targets 
  
# metadata 
print(infrared_thermography_temperature.metadata) 
  
# variable information 
print(infrared_thermography_temperature.variables)
# Out:
# {'uci_id': 925, 'name': 'Infrared Thermography Temperature', 'repository_url': 'https://archive.ics.uci.edu/dataset/925/infrared+thermography+temperature+dataset', 'data_url': 'https://archive.ics.uci.edu/static/public/925/data.csv', 'abstract': 'The Infrared Thermography Temperature Dataset contains temperatures read from various locations of inferred images about patients, with the addition of oral temperatures measured for each individual. The 33 features consist of gender, age, ethnicity, ambiant temperature, humidity, distance, and other temperature readings from the thermal images. The dataset is intended to be used in a regression task to predict the oral temperature using the environment information as well as the thermal image readings. ', 'area': 'Health and Medicine', 'tasks': ['Regression'], 'characteristics': ['Tabular'], 'num_instances': 1020, 'num_features': 33, 'feature_types': ['Real', 'Categorical'], 'demographics': ['Gender', 'Age', 'Ethnicity'], 'target_col': ['av
# ...

# %%
independent_variables = X.shape[1]
dependent_variables = y.shape[1]

print("Number of independent variables:", independent_variables)
print("Number of dependent variables:", dependent_variables)
# Out:
# Number of independent variables: 33
# Number of dependent variables: 2

# %% [markdown]
# 3.4

# %%
import pandas as pd

#calculate nul values for X

X_null_values = X.isna().sum()

# calculate nul values for y

y_null_values = y.isna().sum()

print(X_null_values)
print(y_null_values)
# Out:
# Gender         0
# Age            0
# Ethnicity      0
# T_atm          0
# Humidity       0
# Distance       2
# T_offset1      0
# Max1R13_1      0
# Max1L13_1      0
# aveAllR13_1    0
# aveAllL13_1    0
# T_RC1          0
# T_RC_Dry1      0
# T_RC_Wet1      0
# T_RC_Max1      0
# T_LC1          0
# T_LC_Dry1      0
# T_LC_Wet1      0
# T_LC_Max1      0
# RCC1           0
# LCC1           0
# canthiMax1     0
# canthi4Max1    0
# T_FHCC1        0
# T_FHRC1        0
# T_FHLC1        0
# T_FHBC1        0
# T_FHTC1        0
# T_FH_Max1      0
# T_FHC_Max1     0
# T_Max1         0
# T_OR1          0
# T_OR_Max1      0
# dtype: int64
# aveOralF    0
# aveOralM    0
# dtype: int64

# %%
# Concatenate X and y into a single DataFrame
data = pd.concat([X, y], axis=1)

# Drop rows with missing values in either X or y
data = data.dropna()

# Separate X and y after dropping missing values
X_clean = data[X.columns]  # Convert back to DataFrame
y_clean = data[y.columns]   # Convert back to DataFrame

# %%
X_null_values = X_clean.isna().sum()

# calculate nul values for y

y_null_values = y_clean.isna().sum()

print(X_null_values)
print(y_null_values)
# Out:
# Gender         0
# Age            0
# Ethnicity      0
# T_atm          0
# Humidity       0
# Distance       0
# T_offset1      0
# Max1R13_1      0
# Max1L13_1      0
# aveAllR13_1    0
# aveAllL13_1    0
# T_RC1          0
# T_RC_Dry1      0
# T_RC_Wet1      0
# T_RC_Max1      0
# T_LC1          0
# T_LC_Dry1      0
# T_LC_Wet1      0
# T_LC_Max1      0
# RCC1           0
# LCC1           0
# canthiMax1     0
# canthi4Max1    0
# T_FHCC1        0
# T_FHRC1        0
# T_FHLC1        0
# T_FHBC1        0
# T_FHTC1        0
# T_FH_Max1      0
# T_FHC_Max1     0
# T_Max1         0
# T_OR1          0
# T_OR_Max1      0
# dtype: int64
# aveOralF    0
# aveOralM    0
# dtype: int64

# %%
print(X_clean.shape)

print(y_clean.shape)
# Out:
# (1018, 33)
# (1018, 2)

# %% [markdown]
# 3.5

# %%
dependent = y_clean[["aveOralM"]]
independent = X_clean[["Age", "T_atm", "Humidity", "Distance", "T_offset1"]]

# %%
independent.head()
# Out:
#      Age  T_atm  Humidity  Distance  T_offset1
# 0  41-50   24.0      28.0       0.8     0.7025
# 1  31-40   24.0      26.0       0.8     0.7800
# 2  21-30   24.0      26.0       0.8     0.8625
# 3  21-30   24.0      27.0       0.8     0.9300
# 4  18-20   24.0      27.0       0.8     0.8950

# %% [markdown]
# 3.6

# %%
independent_encoded = pd.get_dummies(independent, drop_first=True)
independent_encoded
# Out:
#       T_atm  Humidity  Distance  T_offset1  Age_21-25  Age_21-30  Age_26-30  \
# 0      24.0      28.0       0.8     0.7025      False      False      False
# 1      24.0      26.0       0.8     0.7800      False      False      False
# 2      24.0      26.0       0.8     0.8625      False       True      False
# 3      24.0      27.0       0.8     0.9300      False       True      False
# 4      24.0      27.0       0.8     0.8950      False      False      False
# ...     ...       ...       ...        ...        ...        ...        ...
# 1015   25.7      50.8       0.6     1.2225       True      False      False
# 1016   25.7      50.8       0.6     1.4675       True      False      False
# 1017   28.0      24.3       0.6     0.1300      False      False      False
# 1018   25.0      39.8       0.6     1.2450      False      False       True
# 1019   23.8      45.6       0.6     0.8675      False      False      False
#
#       Age_31-40  Age_41-50  Age_51-60  Age_>60
# ...

# %%
X_train , X_test , Y_train , Y_test = train_test_split(independent_encoded ,dependent , test_size =0.2 , random_state = 42)

# %% [markdown]
# 3.7

# %%
model = LinearRegression()
model.fit(X_train , Y_train)

coefficients = model.coef_

# Print the coefficients
print("Estimated Coefficients:")
for i, coef in enumerate(coefficients.flatten()):
    print(f"Coefficient for {independent_encoded.columns[i]}: {coef}")
# Out:
# Estimated Coefficients:
# Coefficient for T_atm: 0.00636477031385094
# Coefficient for Humidity: 0.0014354180191543811
# Coefficient for Distance: 0.0025143135455469832
# Coefficient for T_offset1: 0.18279515887175235
# Coefficient for Age_21-25: -0.005293117954369737
# Coefficient for Age_21-30: 0.0751627395989575
# Coefficient for Age_26-30: -0.14829523423206117
# Coefficient for Age_31-40: -0.026279909784433047
# Coefficient for Age_41-50: -0.09644371345033831
# Coefficient for Age_51-60: -0.32560687421308787
# Coefficient for Age_>60: -0.20310069308964

# %%
new_independent = X_clean[["T_OR1", "T_OR_Max1", "T_FHC_Max1", "T_FH_Max1"]]
new_independent
# Out:
#         T_OR1  T_OR_Max1  T_FHC_Max1  T_FH_Max1
# 0     35.6350    35.6525     34.0075    34.5300
# 1     35.0925    35.1075     34.6600    34.6825
# 2     35.8600    35.8850     35.2225    35.3450
# 3     34.9650    34.9825     35.3150    35.6025
# 4     35.5875    35.6175     35.3725    35.4175
# ...       ...        ...         ...        ...
# 1015  35.6775    35.7100     35.7475    35.8525
# 1016  36.4525    36.4900     35.5525    35.7650
# 1017  35.9650    35.9975     35.7100    36.3750
# 1018  35.4150    35.4350     35.3100    35.4150
# 1019  35.8900    35.9175     35.1175    35.1525
#
# [1018 rows x 4 columns]

# %% [markdown]
# 3.9

# %%
X_train , X_test , Y_train , Y_test = train_test_split(new_independent ,dependent , test_size =0.2 , random_state = 42)

model = LinearRegression()
model.fit(X_train , Y_train)

coefficients = model.coef_

# Print the coefficients
print("Estimated Coefficients:")
for i, coef in enumerate(coefficients.flatten()):
    print(f"Coefficient for {new_independent.columns[i]}: {coef}")
# Out:
# Estimated Coefficients:
# Coefficient for T_OR1: 0.20545776323995343
# Coefficient for T_OR_Max1: 0.34819684316001903
# Coefficient for T_FHC_Max1: -0.08371846705362082
# Coefficient for T_FH_Max1: 0.3765643420653231

# %% [markdown]
# 3.10

# %%
N=len(Y_train)
d = X_train.shape[1]

#RSS

Y_pred = model.predict(X_test)
residuals = Y_test.to_numpy() - Y_pred

RSS = np.sum(residuals ** 2)
print("Residual Sum of Squares (RSS):", RSS)

#RSE
RSE = np.sqrt(1/(N-d-1)*RSS)
print('RSE=', RSE)

#MSE

MSE = np.mean(residuals ** 2)
print("Mean Squared Error (MSE):", MSE)

# Total Sum of Squares (TSS)
TSS = np.sum((Y_train.to_numpy() - np.mean(Y_train.to_numpy()))**2)


# R-squared

R2 = 1 - (RSS/TSS)
print("R-squared:", R2)
# Out:
# Residual Sum of Squares (RSS): 15.923399754377353
# RSE= 0.14029546674991922
# Mean Squared Error (MSE): 0.0780558811489086
# R-squared: 0.9287986830855307

# %%
import pandas as pd
import statsmodels.api as sm


X_test_constant = sm.add_constant(X_test)

ols_model = sm.OLS(Y_test, X_test_constant).fit()
summary = ols_model.summary()
p_values = summary.tables[1].data[1:]

p_values_df = pd.DataFrame(p_values, columns=['Feature', 'Coefficient', 'Standard Error', 't-value', 'P-Value', 'Lower CI', 'Upper CI'])
p_values_df['P-Value'] = p_values_df['P-Value'].astype(float)

print(summary)
print(p_values_df)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               aveOralM   R-squared:                       0.623
# Model:                            OLS   Adj. R-squared:                  0.616
# Method:                 Least Squares   F-statistic:                     82.36
# Date:                Mon, 02 Sep 2024   Prob (F-statistic):           3.97e-41
# Time:                        22:27:41   Log-Likelihood:                -25.136
# No. Observations:                 204   AIC:                             60.27
# Df Residuals:                     199   BIC:                             76.86
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         10.6089      1.510      7.025      0.000       7.631      13.587
# ...
